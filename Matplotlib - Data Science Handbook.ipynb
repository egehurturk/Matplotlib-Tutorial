# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# # Introduction to Matplotlib

# %% [markdown]
# ## Setting Styles

# %%
# This function uses the classic matplotlib style
plt.style.use('classic')

# %% [markdown]
# ## show() or No show()? How to Display Your Plots?

# %% [markdown]
# ### Running from a Script

# %% [markdown]
# When you are using matplotlib directly from a code editor or an IDE (script), use `plt.show()`.

# %%
# -------- file: myplot.py ---------
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,10,100)
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
plt.show()

# %% [markdown]
# then use $ python myplot.py\
# * Note: you should use `plt.show()` only once and at the end of the script!

# %% [markdown]
# ### Running from Jupyter Notebooks

# %% [markdown]
# We can use the `%matplotlib inline` command to specify Matplotlib mode, or use `%matplotlib notebook` to create interactive charts.
# * `%matplotlib inline` will lead to static images of your plot
# * `%matplotlib notebook` will lea to interactive plots embedded within the notebook`

# %%
# %matplotlib inline

# %%
x = np.linspace(0,10,100)
fig = plt.figure()
plt.plot(x, np.sin(x), ':')
plt.plot(x, np.cos(x), '-')

# %% [markdown]
# ## Saving Figures to a File

# %%
fig.savefig('my_figure.png')

# %%
# !ls
# Out:
# Matplotlib - Data Science Handbook.ipynb
# README.md
# my_figure.png

# %% [markdown]
# As you can see, here's our my_figure image!

# %%
from IPython.display import Image
Image('my_figure.png')

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'ps': 'Postscript',
#  'eps': 'Encapsulated Postscript',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %% [markdown]
# ## Two Styles of Using Matplotlib

# %% [markdown]
# 1. MATLAB-style Interface
# 2. Object-oriented Interface

# %% [markdown]
# ### MATLAB style:

# %% [markdown]
# Matlab style tools are contained in the `pyplot` module. This style is the usual style we use (the pyplot package)

# %%
plt.figure() # Creates a figure
plt.subplot(2,1,1) # Is used to create subplots, 2,1,1 specifies that we want 2 rows, 1 columns, and the plot just below the code is the first column
plt.plot(x, np.sin(x), ':r')

plt.subplot(2,1,2)
plt.plot(x, np.cos(x), 'b')

# %%
plt.gcf() # Get current figure

# %% [markdown]
# ### Object Oriented Style:

# %% [markdown]
# This style is used when you want to have more control on your styles.

# %%
# First, create a grid of plots
# ax will be an array of two Axes objects:
fig,ax = plt.subplots(2)

# Calling `plot()` method on the appropiate object
ax[0].plot(x, np.sin(x), ':r')
ax[1].plot(x, np.cos(x), 'b')

# %% [markdown]
# # Simple Line Plots

# %% [markdown]
# the easist plots, $y = f(x)$.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid') # Another type of style
import numpy as np

# %%
fig = plt.figure()
ax = plt.axes()

# %% [markdown]
# The figure can be thought of as a container that contains all the objects representing axes, graphics, text, and labels. The axes is what we see above: a bounding box, graph with ticks that contain the plot emlements

# %%
fig = plt.figure()
ax = plt.axes()
x = np.linspace(0,10,100)
ax.plot(x, np.sin(x))

# %%
# To create multiple lines:
plt.plot(x, np.cos(x), 'b')
plt.plot(x, np.sin(x), ':r')

# %% [markdown]
# ## Adjusting the Plot

# %%
plt.plot(x, np.sin(x - 0), color='blue')        # specify color by name
plt.plot(x, np.sin(x - 1), color='g')           # short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75')        # Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44')     # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 to 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # all HTML color names supported

# %% [markdown]
# If no color is specified, matplotlib will use a cycle of colors

# %%
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');

# For short, you can use the following codes:
plt.plot(x, x + 4, linestyle='-')  # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':');  # dotted

# %% [markdown]
# We can combine these `linestyle` and `color` keyword arguments into one single argument:

# %%
plt.plot(x, x + 0, '-g')  # solid green
plt.plot(x, x + 1, '--c') # dashed cyan
plt.plot(x, x + 2, '-.k') # dashdot black
plt.plot(x, x + 3, ':r');  # dotted red

# %% [markdown]
# Colors are represented in RGB (Red/Green/Blue) and CMYK (Cyan/Magenta/Yellow/blacK)

# %%
# ?plt.plot to search for more examples

# %% [markdown]
# ## Adjusting the Plot: Axes Limits

# %%
plt.plot(x, np.sin(x))

plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5)
# Out:
# (-1.5, 1.5)

# %%
# Reverse:
plt.plot(x, np.sin(x))
plt.xlim(10, 0)
plt.ylim(1.2, -1.2)
# Out:
# (1.2, -1.2)

# %%
# A combination of those two:
plt.plot(x, np.sin(x))
plt.axis([-1, 11, -5, 18])
# Out:
# [-1, 11, -5, 18]

# %% [markdown]
# Where `plot.axis()` gets [`xmin`, `xmax`. `ymin`, `ymax`]

# %% [markdown]
# ## Labelling plots

# %%
plt.plot(x, np.sin(x), ':r')
plt.title('Sine Curve!') # Creates a title for the plot
plt.xlabel('x') # Creates a x label for the plot
plt.ylabel('sin(x)') # Creates a y label for the plot
# Out:
# Text(0, 0.5, 'sin(x)')

# %%
# Creating Legends:
plt.plot(x, np.sin(x), ':r', label='sin(x)') # Label is useful when you are defining the legend
plt.plot(x, np.cos(x), 'b', label='cos(x)')
plt.axis('equal')
plt.legend()

# %% [markdown]
# Matplotlib styles: [Styles](https://matplotlib.org/3.2.1/gallery/style_sheets/style_sheets_reference.html)

# %% [markdown]
# # Simple Scatter Plots

# %% [markdown]
# ## Scatter plots with `plt.plot`

# %% [markdown]
# We can use the `plt.plot` for scatter plots as well

# %%
x = np.linspace(0,10,30)
y = np.sin(x)
plt.plot(x,y,'o', color='black')
plt.axis('tight')
# Out:
# (0.0, 10.0, -0.9933721339045803, 0.9970328976918713)

# %%
rng = np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker,
             label="marker='{0}'".format(marker))
plt.legend(numpoints=1)
plt.xlim(0, 1.8);

# %% [markdown]
# These are the symbols that we can use

# %% [markdown]
# Even we can use the combination of these symbols:

# %%
plt.plot(x, y, '-ok')

# %%
plt.plot(x, y, '-p', color='gray',
         markersize=15, linewidth=4,
         markerfacecolor='white',
         markeredgecolor='gray',
         markeredgewidth=2)
plt.ylim(-1.2, 1.2);

# %% [markdown]
# ## Scatter Plotting using `plt.scatter()`

# %%
plt.scatter(x, y, marker='o')

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.3,
            cmap='viridis')
plt.colorbar();  # show color scale

# %% [markdown]
# ## `plt.plot()` Versus `plt.scatter()`

# %% [markdown]
# For small amounts of data, it will not matter when it comes to efficiency. But, when we have large data, `plt.plot()` can be more efficient than `plt.scatter()`. Read more at: [plot versus scatter](https://github.com/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/04.02-Simple-Scatter-Plots.ipynb)

# %% [markdown]
# # Visualizing Errors:

# %% [markdown]
# ## Basic Errorbars:

# %%
x = np.linspace(0,10,50)
dy = 0.8
y=np.sin(x) + dy*np.random.randn(50)

# Errorbar
plt.errorbar(x, y, yerr=dy, fmt='.k')
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# Here, the `fmt` is a format code controlling the apperance of lines and points.

# %% [markdown]
# You can custimaze your bars:

# %%
plt.errorbar(x, y, yerr=dy, fmt='o', color='black',
             ecolor='lightgray', elinewidth=3, capsize=0);

# %% [markdown]
# ## Continuous Errors

# %% [markdown]
# Refer to book p.240

# %% [markdown]
# ## Density and Contour Plots

# %% [markdown]
# * `plt.contour` for contour plots,
# * `plt.contourf` for filled contour plots.
# * `plt.imshow` for showing images

# %% [markdown]
# ## Visualizing a Three-Dimensional Function

# %% [markdown]
# We will plot a function $z=f(x,y)$, using the following particular choice for $f$

# %%
def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

# %%
x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %%
plt.contour(X,Y,Z, colors='black')

# %%
plt.contour(X,Y,Z,20,cmap='RdGy')

# %% [markdown]
# We can fill in these lines:

# %%
plt.contourf(X,Y,Z,20,cmap='RdGy')
plt.colorbar()

# %%
plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower',
           cmap='RdGy')
plt.colorbar()
plt.axis(aspect='image');

# %% [markdown]
# There are a few potential gotchas with imshow(), however:
#
# * `plt.imshow()` doesn't accept an x and y grid, so you must manually specify the extent `[xmin, xmax, ymin, ymax]` of the image on the plot.
# * `plt.imshow()` by default follows the standard image array definition where the origin is in the upper left, not in the lower left as in most contour plots. This must be changed when showing gridded data.
# * `plt.imshow()` will automatically adjust the axis aspect ratio to match the input data; this can be changed by setting, for example, `plt.axis(aspect='image')` to make x and y units match.

# %% [markdown]
# ## Histograms, Bindings, etc

# %% [markdown]
# Look to the pages 247,8 in the book

# %% [markdown]
# # Customizing Plot Legends

# %%
x = np.linspace(0, 10, 1000)
fig, ax = plt.subplots()
ax.plot(x, np.sin(x), '-b', label='Sine')
ax.plot(x, np.cos(x), '--r', label='Cosine')
ax.axis('equal')
leg = ax.legend();

# %% [markdown]
# This is a default Plot Legend

# %%
ax.legend(loc='upper left', frameon=True)
fig

# %%
# Use ncol to specifiy the number of columns
ax.legend(frameon=False, loc='lower center', ncol=2)
fig

# %%
# Add a fancybox:
ax.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1, frameon=True)
fig

# %% [markdown]
# ## Choosing elements for the Legend:

# %% [markdown]
# Look for the book pages 251,252

# %% [markdown]
# ## Legend Size of Points:

# %% [markdown]
# Example code can be found in here: [Example](https://github.com/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/04.06-Customizing-Legends.ipynb)

# %% [markdown]
# ## Multiple Legends:

# %%
fig, ax = plt.subplots()

lines = []
styles = ['-', '--', '-.', ':']
x = np.linspace(0, 10, 1000)

colors = ['red', 'black', 'blue', 'magenta']
for i in range(4):
    lines += ax.plot(x, np.sin(x - i * np.pi / 2), styles[i], color=colors[i])
ax.axis('equal')

# specify the lines and labels of the first legend
ax.legend(lines[:2], ['line A', 'line B'],
          loc='upper right', frameon=False)

# Create the second legend and add the artist manually.
from matplotlib.legend import Legend
leg = Legend(ax, lines[2:], ['line C', 'line D'],
             loc='lower right', frameon=False)
ax.add_artist(leg);

# %% [markdown]
# # Customizing Colorbars

# %% [markdown]
# The simplest colorbar is using the `plt.colorbar` method. This method creates a new axis which is the colorbar itself

# %%
x = np.linspace(1, 10, 1000)
I = np.sin(x) * np.cos(x[:, np.newaxis])
plt.imshow(I)
plt.colorbar()

# %% [markdown]
# ## Customizing the Colorbars

# %% [markdown]
# We can use the `cmap` argument to specify the colormap:

# %%
plt.imshow(I, cmap='gray')

# %% [markdown]
# ### Choosing the Colormap:

# %% [markdown]
# Refer to this link: [10 rules for better graphics](https://journals.plos.org/ploscompbiol/article?id=10.1371/journal.pcbi.1003833) to the choice of colors, etc.
# \
# \
# There are different categories of colormaps:
# * *Sequential Colormaps*:
#     * These consist of one continuous sequence of colors (binary or viridis).
# * *Divergent Colormaps*:
#     * These usually contain 2 distinct colors, which show + or - RdBu or PuOr).
# * *Qualitive Colormaps*:
#     * Mix colors, no sequence (rainbow or jet).

# %%
from matplotlib.colors import LinearSegmentedColormap
def grayscale_cmap(cmap):
    """Return a grayscale version of the given colormap"""
    cmap = plt.cm.get_cmap(cmap)
    colors = cmap(np.arange(cmap.N))
    
    # convert RGBA to perceived grayscale luminance
    # cf. http://alienryderflex.com/hsp.html
    RGB_weight = [0.299, 0.587, 0.114]
    luminance = np.sqrt(np.dot(colors[:, :3] ** 2, RGB_weight))
    colors[:, :3] = luminance[:, np.newaxis]
        
    return LinearSegmentedColormap.from_list(cmap.name + "_gray", colors, cmap.N)
    

def view_colormap(cmap):
    """Plot a colormap with its grayscale equivalent"""
    cmap = plt.cm.get_cmap(cmap)
    colors = cmap(np.arange(cmap.N))
    
    cmap = grayscale_cmap(cmap)
    grayscale = cmap(np.arange(cmap.N))
    
    fig, ax = plt.subplots(2, figsize=(6, 2),
                           subplot_kw=dict(xticks=[], yticks=[]))
    ax[0].imshow([colors], extent=[0, 10, 0, 1])
    ax[1].imshow([grayscale], extent=[0, 10, 0, 1])

# %%
view_colormap('jet')

# %% [markdown]
# Notice the bright stripes in the grayscale image. Even in full color, this uneven brightness means that the eye will be drawn to certain portions of the color range, which will potentially emphasize unimportant parts of the dataset. It's better to use a colormap such as `viridis` (the default as of Matplotlib 2.0), which is specifically constructed to have an even brightness variation across the range. Thus it not only plays well with our color perception, but also will translate well to grayscale printing:

# %%
view_colormap('viridis')

# %%
view_colormap('cubehelix')

# %% [markdown]
# If you favor rainbow schemes, another good option for continuous data is the cubehelix colormap:

# %%
view_colormap('RdBu')

# %% [markdown]
# For other situations, such as showing positive and negative deviations from some mean, dual-color colorbars such as RdBu (Red-Blue) can be useful. However, as you can see in the following figure, it's important to note that the positive-negative information will be lost upon translation to grayscale!

# %% [markdown]
# ### Color Limits and Extensions

# %% [markdown]
# Look at the pages 257, 258 for more info

# %% [markdown]
# # Multiple Subplots
